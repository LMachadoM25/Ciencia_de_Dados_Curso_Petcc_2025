# %%
# Importando a biblioteca
import pandas as pd

# Lendo o arquivo com os dados
df = pd.read_csv('dataset_exemplos_limpo.csv')

# %% [markdown]
# # **1.**

# %%
display(df.head())
# Out:
#    ID_Aluno                Nome  Ano_Ingresso  Ano_Saida_Esperado  \
# 0         1     Cecília da Cruz          2024                2029
# 1         2      Melissa Vieira          2021                2026
# 2         3          Théo Jesus          2022                2027
# 3         4  José Miguel Campos          2024                2028
# 4         5         Bruna Brito          2020                2026
#
#    Periodo_Atual                   Curso Fraternidade   CRA  Possui_Bolsa  \
# 0              3              Psicologia      Epsilon  7.08          True
# 1              9  Engenharia de Software        Delta  7.84         False
# 2              7  Engenharia de Software        Gamma  7.68         False
# 3              3              Psicologia        Gamma  8.33          True
# 4             11   Ciência da Computação      Epsilon  7.61         False
#
#    Taxa_Mensalidade  Horas_Atividade_Extra
# 0           1640.98                     13
# ...

# %% [markdown]
# # **2.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID_Aluno               500 non-null    int64
#  1   Nome                   500 non-null    object
#  2   Ano_Ingresso           500 non-null    int64
#  3   Ano_Saida_Esperado     500 non-null    int64
#  4   Periodo_Atual          500 non-null    int64
#  5   Curso                  500 non-null    object
#  6   Fraternidade           500 non-null    object
#  7   CRA                    500 non-null    float64
#  8   Possui_Bolsa           500 non-null    bool
#  9   Taxa_Mensalidade       500 non-null    float64
#  10  Horas_Atividade_Extra  500 non-null    int64
# dtypes: bool(1), float64(2), int64(5), object(3)
# memory usage: 39.7+ KB

# %% [markdown]
# # **3.**

# %%
df.describe()
# Out:
#          ID_Aluno  Ano_Ingresso  Ano_Saida_Esperado  Periodo_Atual  \
# count  500.000000     500.00000          500.000000     500.000000
# mean   250.500000    2021.53600         2026.540000       7.928000
# std    144.481833       2.33315            2.459369       4.666301
# min      1.000000    2018.00000         2020.000000       1.000000
# 25%    125.750000    2020.00000         2025.000000       3.000000
# 50%    250.500000    2021.00000         2027.000000       9.000000
# 75%    375.250000    2024.00000         2029.000000      11.000000
# max    500.000000    2025.00000         2031.000000      15.000000
#
#               CRA  Taxa_Mensalidade  Horas_Atividade_Extra
# count  500.000000        500.000000             500.000000
# mean     8.102520       2284.714540              10.064000
# std      0.748436       1600.769846               5.944289
# min      1.500000        991.740000               0.000000
# 25%      7.680000       1502.560000               5.000000
# ...

# %% [markdown]
# # **4.**

# %%
display(df['ID_Aluno']),
display(df['Nome']),
display(df['CRA'])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: ID_Aluno, Length: 500, dtype: int64
# 0          Cecília da Cruz
# 1           Melissa Vieira
# 2               Théo Jesus
# 3       José Miguel Campos
# 4              Bruna Brito
#               ...
# 495    Enzo Gabriel Cirino
# 496          Elisa Freitas
# 497           Dante Pastor
# 498          Isabela Alves
# 499    Ana Carolina Campos
# Name: Nome, Length: 500, dtype: object
# 0      7.08
# 1      7.84
# 2      7.68
# 3      8.33
# 4      7.61
#        ...
# 495    7.74
# 496    7.59
# 497    8.96
# 498    8.48
# 499    8.41
# Name: CRA, Length: 500, dtype: float64

# %% [markdown]
# # **5.**

# %%
print('Saída para a coluna curso')
display(df['Curso'].value_counts())
# Out:
# Saída para a coluna curso
# Curso
# Engenharia de Software    125
# Ciência da Computação     117
# Psicologia                 81
# Direito                    81
# Administração              65
# Medicina                   31
# Name: count, dtype: int64

# %% [markdown]
# # **6.**

# %% [markdown]
# Do total de 6 cursos e 500 alunos temos, os dados anteriores

# %% [markdown]
# # **7.**

# %%
df_aluno = df[df['CRA'] > 8]

df_aluno
# Out:
#      ID_Aluno                    Nome  Ano_Ingresso  Ano_Saida_Esperado  \
# 3           4      José Miguel Campos          2024                2028
# 6           7             Cauã Vargas          2022                2027
# 7           8           Pietra da Luz          2022                2027
# 9          10           Enzo Nogueira          2019                2024
# 10         11             Joana Abreu          2020                2026
# ..        ...                     ...           ...                 ...
# 491       492       Ana Lívia Pimenta          2022                2027
# 492       493  Luiz Henrique Mendonça          2018                2022
# 497       498            Dante Pastor          2021                2026
# 498       499           Isabela Alves          2018                2023
# 499       500     Ana Carolina Campos          2021                2027
#
#      Periodo_Atual                   Curso Fraternidade   CRA  Possui_Bolsa  \
# ...

# %% [markdown]
# # **8.**

# %%
df_aluno = df[df['Possui_Bolsa'] == True]

df_aluno
# Out:
#      ID_Aluno                 Nome  Ano_Ingresso  Ano_Saida_Esperado  \
# 0           1      Cecília da Cruz          2024                2029
# 3           4   José Miguel Campos          2024                2028
# 5           6    Ravi Lucca Barros          2025                2029
# 6           7          Cauã Vargas          2022                2027
# 7           8        Pietra da Luz          2022                2027
# ..        ...                  ...           ...                 ...
# 487       488          Lívia Pires          2021                2027
# 488       489         Levi Pereira          2018                2022
# 489       490  Maria Sophia Cirino          2022                2028
# 494       495   Maria Luísa da Luz          2022                2027
# 498       499        Isabela Alves          2018                2023
#
#      Periodo_Atual                   Curso Fraternidade   CRA  Possui_Bolsa  \
# ...

# %% [markdown]
# # **9.**

# %%
df_alunos = df[df['Curso'] == 'Psicologia']
df_alunos = df_alunos[df_alunos['CRA'] > 7.5]

df_alunos
# Out:
#      ID_Aluno                      Nome  Ano_Ingresso  Ano_Saida_Esperado  \
# 3           4        José Miguel Campos          2024                2028
# 10         11               Joana Abreu          2020                2026
# 11         12            Isabela Moraes          2024                2030
# 26         27      Lucas Gabriel Campos          2023                2027
# 27         28         Giovanna Ferreira          2019                2024
# ..        ...                       ...           ...                 ...
# 470       471          Fernanda Machado          2022                2027
# 478       479  Arthur Miguel Nascimento          2018                2023
# 481       482            Alexia Pimenta          2023                2028
# 484       485              Enrico Lopes          2022                2027
# 490       491            Augusto Castro          2025                2030
#
#      Periodo_Atual       Curso Fraternidade   CRA  Possui_Bolsa  \
# ...

# %% [markdown]
# # **10.**

# %%
df_aluno = df[df['Taxa_Mensalidade'] > 2500]

df_aluno
# Out:
#      ID_Aluno                      Nome  Ano_Ingresso  Ano_Saida_Esperado  \
# 1           2            Melissa Vieira          2021                2026
# 9          10             Enzo Nogueira          2019                2024
# 13         14     Pedro Henrique Cirino          2020                2025
# 16         17  Sr. João Vitor Fernandes          2021                2026
# 17         18       João Gabriel Cirino          2025                2029
# ..        ...                       ...           ...                 ...
# 472       473            Nathan Almeida          2020                2025
# 475       476            Thales Pacheco          2025                2029
# 476       477              Breno Vargas          2018                2023
# 493       494              Lunna Castro          2023                2027
# 494       495        Maria Luísa da Luz          2022                2027
#
#      Periodo_Atual                   Curso Fraternidade   CRA  Possui_Bolsa  \
# ...

# %% [markdown]
# # **11.**

# %%
df_cursos = df.groupby('Curso')
df_cursos_media = df_cursos[['CRA']].mean().round(3)
df_cursos_media
# Out:
#                           CRA
# Curso
# Administração           8.073
# Ciência da Computação   8.158
# Direito                 8.080
# Engenharia de Software  8.141
# Medicina                8.081
# Psicologia              8.018

# %% [markdown]
# # **12.**

# %%
df_cursos = df.groupby('Periodo_Atual')
df_cursos_media = df_cursos[['Horas_Atividade_Extra']].mean().round(3)
df_cursos_media
# Out:
#                Horas_Atividade_Extra
# Periodo_Atual
# 1                             11.194
# 3                             10.310
# 5                             11.613
# 7                              9.941
# 9                              9.776
# 11                             8.875
# 13                             9.152
# 15                             9.423

# %% [markdown]
# # **13.**

# %%
display(df['Ano_Ingresso'].value_counts().sort_index())
# Out:
# Ano_Ingresso
# 2018    71
# 2019    46
# 2020    64
# 2021    76
# 2022    51
# 2023    62
# 2024    58
# 2025    72
# Name: count, dtype: int64

# %% [markdown]
# # **Matplot**

# %% [markdown]
# ## **a)**

# %%
import matplotlib.pyplot as plt

#categorias = ['Engenharia de Software', 'Ciência da Computação', 'Psicologia', 'Direito', 'Administração', 'Medicina']
#valores = [125, 117, 81, 81, 65, 31]

df['Curso'] = df['Curso'].str.title()
curso_counts = df['Curso'].value_counts()

plt.xticks(rotation=44)
plt.bar(categorias, valores, color='skyblue')
plt.title("Gráfico de Barras")
plt.xlabel("Cursos")
plt.ylabel("N° de alunos")
plt.show()

# %% [markdown]
# ## **b)**

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Taxa_Mensalidade'], bins=50, color='skyblue', edgecolor='black')
plt.title("Alunos por Taxa de Mensalidade")
plt.xlabel("Mensalidade(R$)")
plt.ylabel("N° Alunos")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## **c)** Quais são os valores que variam nas mensalidades para cada curso?

# %%
np.random.seed(10)
dados1 = np.random.normal(100, 10, 200)
dados2 = np.random.normal(90, 20, 200)
dados3 = np.random.normal(110, 5, 200)

plt.boxplot([dados1, dados2, dados3], labels=['Grupo 1', 'Grupo 2', 'Grupo 3'])
plt.title("Boxplot Comparativo")
plt.ylabel("Valores")
plt.grid(True)
plt.show()
